# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries.
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Replace_cutoff replaces outliers from a dataset using an arbitrary cutoff point
def replace_cutoff(df,cutoff):
    outliers = (df - cutoff)>0
    df[outliers] = cutoff
    return df

def

# %%
new = pd.read_csv("categorized_output.csv")
#new.head()

# %%
new.groupby("Pred_Sub_Cat")["price_dollar"].count().sort_values(ascending=False)
# Out:
# Pred_Sub_Cat
# Other           50489
# Weed            12652
# MDMA             9916
# Cocaine          3916
# LSD              3831
# Benzos           3697
# Amphetamine      2018
# NBOMe            1864
# Speed            1745
# Heroin           1468
# Testosterone     1245
# Xanax            1162
# 2C               1116
# DMT              1049
# Methylone         905
# Viagra            852
# Tramadol          744
# Valium            728
# Name: price_dollar, dtype: int64

# %%
print new[new["Pred_Sub_Cat"]=="Weed"]["PPW"].describe()

new[new["Pred_Sub_Cat"]=="Weed"]["PPW"].hist(bins = 20)
plt.suptitle('Weed, Price per Gram', fontsize=14, fontweight='bold')
plt.show()
# Out:
# count    10278.000000
# mean       112.225754
# std       1455.709547
# min          0.000000
# 25%          8.774425
# 50%         12.416679
# 75%         18.448000
# max      57532.000000
# Name: PPW, dtype: float64

# %%
#Replace all values above a certain PPWC with cutoff value
new.ix[new.Pred_Sub_Cat=="Weed", 'PPW'] = replace_cutoff(new.ix[new.Pred_Sub_Cat=="Weed", 'PPW'],100)

print new[new["Pred_Sub_Cat"]=="Weed"]["PPW"].describe()

new[new["Pred_Sub_Cat"]=="Weed"]["PPW"].hist(bins = 20)
plt.suptitle('Weed, Price per Gram', fontsize=14, fontweight='bold')
plt.show()
# Out:
# count    10278.000000
# mean        16.934545
# std         16.514629
# min          0.000000
# 25%          8.774425
# 50%         12.416679
# 75%         18.448000
# max        100.000000
# Name: PPW, dtype: float64

# %%
print new[new["Pred_Sub_Cat"]=="MDMA"]["PPWC"].describe()

new[new["Pred_Sub_Cat"]=="MDMA"]["PPWC"].hist(bins = 20)
plt.suptitle('MDMA, Price per Gram', fontsize=14, fontweight='bold')
plt.show()
# Out:
# count      8264.000000
# mean        174.072485
# std        2532.746984
# min           0.000000
# 25%          19.390000
# 50%          27.974286
# 75%          48.556000
# max      174328.571429
# Name: PPWC, dtype: float64

# %%
#Replace all values above a certain PPWC with cutoff value
new.ix[new.Pred_Sub_Cat=="MDMA", 'PPWC'] = replace_cutoff(new.ix[new.Pred_Sub_Cat=="MDMA", 'PPWC'],200)

print new[new["Pred_Sub_Cat"]=="MDMA"]["PPWC"].describe()

new[new["Pred_Sub_Cat"]=="MDMA"]["PPWC"].hist(bins = 20)
plt.suptitle('MDMA, Price per Gram', fontsize=14, fontweight='bold')
plt.show()
# Out:
# count    8264.000000
# mean       48.418591
# std        51.995637
# min         0.000000
# 25%        19.390000
# 50%        27.974286
# 75%        48.556000
# max       200.000000
# Name: PPWC, dtype: float64

# %%
print new[new["Pred_Sub_Cat"]=="Cocaine"]["PPW"].describe()

new[new["Pred_Sub_Cat"]=="Cocaine"]["PPW"].hist(bins = 20)
plt.suptitle('Cocaine, Price per Gram', fontsize=14, fontweight='bold')
plt.show()
# Out:
# count      3537.000000
# mean        208.308031
# std        2964.565680
# min           0.000000
# 25%          84.613333
# 50%         105.030000
# 75%         149.014000
# max      168360.000000
# Name: PPW, dtype: float64

# %%
#Replace all values above a certain PPWC with cutoff value
new.ix[new.Pred_Sub_Cat=="Cocaine", 'PPW'] = replace_cutoff(new.ix[new.Pred_Sub_Cat=="Cocaine", 'PPW'],500)

print new[new["Pred_Sub_Cat"]=="Cocaine"]["PPW"].describe()

new[new["Pred_Sub_Cat"]=="Cocaine"]["PPW"].hist(bins = 20)
plt.suptitle('Weed, Price per Gram', fontsize=14, fontweight='bold')
plt.show()
# Out:
# count    3537.000000
# mean      134.837921
# std        91.491257
# min         0.000000
# 25%        84.613333
# 50%       105.030000
# 75%       149.014000
# max       500.000000
# Name: PPW, dtype: float64

# %%
x=pd.DataFrame(new.groupby("vendor")["price_dollar"].count().sort_values(ascending=False))
x.columns = ["Listings"]
x=x.reset_index()

# %%
bins = [0,1,10,100,10000]
vend_group = ["Low","Medium","High","Very High"]

x["Listing_Groups"] = pd.cut(x['Listings'], bins, labels=vend_group)

# %%
new2 = pd.merge(new,x,on="vendor")

# %%
new2.shape
# Out:
# (100000, 20)

# %%
new[new["Pred_Sub_Cat"]=="Cocaine"]["PPW"].hist(bins = 20)
plt.suptitle('Cocaine, Price per Gram', fontsize=14, fontweight='bold')
plt.show()

# %%
# y = new2[new2["Listing_Groups"].isin(["Medium","Low"])]
# y[y["Pred_Sub_Cat"]=="Cocaine"]["PPW"].hist(bins = 20)
# plt.suptitle('Cocaine, Price per Gram', fontsize=14, fontweight='bold')
# plt.show()

# %%
#type(new["date"][1])
new["date"] = pd.to_datetime(new["date"])

# %%
y = new[new["Pred_Sub_Cat"]=="Cocaine"]["PPWC"].groupby(new["date"]).mean()
y.plot()

# %%
pd.rolling_mean(y,window=5).plot()
