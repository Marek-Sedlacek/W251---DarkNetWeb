# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

# General libraries.
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# SK-learn libraries for learning.
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.grid_search import GridSearchCV

# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report

# SK-learn library for importing the newsgroup data.
from sklearn.datasets import fetch_20newsgroups

# SK-learn libraries for feature extraction from text.
from sklearn.feature_extraction.text import *

# %%
new = pd.read_csv("cleaned_output.csv")
new.head()
# Out:
#                          title_date category              date       market  \
# 0  2cdcc469ef79378b8daa2accf657dbfd      NaN  10/26/2014 19:00  Silk Road 2
# 1  67b9e2d7823f022055171e68f9dc7c81      NaN   8/26/2014 19:00  Silk Road 2
# 2  9f3552e9f27fda3b83ac8d74e3821829  Alcohol   1/15/2014 18:00  Silk Road 2
# 3  e2e83eb0a80e26976bfeb700cba54bce      NaN   9/14/2014 19:00  Silk Road 2
# 4  d394565b83e410c446d7aa847e53c5df      DMT   10/3/2014 19:00  Silk Road 2
#
#       price  price_dollar         ships_from  \
# 0    4.3849     1530.2000                NaN
# 1  0.015625        7.9755                NaN
# 2   0.65731      556.9800  PHISHING WARNING:
# 3    4.7957     2260.5000                NaN
# 4    0.0231        7.5188     United Kingdom
#
#                                             ships_to  \
# 0                                                NaN
# 1                                                NaN
# 2  Confirm that your browser is pointed to our re...
# 3                                                NaN
# 4                                          Worldwide
#
#                                     title       vendor   Weight  Count  \
# 0            EU Passport 1:1 Good quality   threekings      NaN      1
# 1      The Walking Dead Seasons 1-4 (AVI)  wakeside917      NaN      1
# 2         Custom order for foryoumyfr13nd  Alexmack380      NaN      1
# 3  250tabs x 250ug LSD ---FREE POSTAGE---  top_gear_uk  0.00025    250
# 4            Breakthrough DMT sample 50mg            9  0.05000      1
#
#    SubCat2          Cat2          PPW       PPWC
# 0      NaN           NaN          NaN        NaN
# 1      NaN           NaN          NaN        NaN
# 2  Alcohol         Other          NaN        NaN
# 3      LSD  Psychadelics  9042000.000  36168.000
# 4      DMT  Psychadelics      150.376    150.376

# %%
new2 = new[pd.isnull(new["Cat2"])==False]
categories = ["Stimulants", "Ecstasy", "Cannabis", "Psychadelics", "Relaxants", "Opioids", 
              "Sildenafil Citrate","Dissociatives","Analgesics","Steroids / PEDs"]
# new2 = new[new["Cat2"].isin(categories)]
len(new2)
# Out:
# 62601

# %%
new2["Cat2"] = [x if x in categories else "Other" for x in new2["Cat2"]]
#new2
# Out:
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data = new2["title"].as_matrix()
labels = new2["Cat2"].as_matrix()

num_test = len(data)
test_data, test_labels = data[:num_test/4], labels[:num_test/4]
train_data, train_labels = data[num_test/4:], labels[num_test/4:]

print num_test
print len(test_data)
print len(train_data)
# Out:
# 62601
# 15650
# 46951

# %%
train_labels
# Out:
# array(['Ecstasy', 'Dissociatives', 'Ecstasy', ..., 'Opioids', 'Other',
#        'Other'], dtype=object)

# %%
#Initialize Count Vectorizer
vectorizer = TfidfVectorizer()
x=vectorizer.fit_transform(train_data)

#Find optimal alpha for Multinomial NB model
for i in [0.000001,0.0001,0.005,0.0075,0.01,0.03,0.05,0.1,0.5,1]:
    Mult = MultinomialNB(alpha=i)
    Mult.fit(vectorizer.transform(train_data), train_labels) 
    preds = Mult.predict(vectorizer.transform(test_data))
    
    print "For alpha %f, the f1 score is %f" %(i, metrics.f1_score(test_labels,preds,average="weighted"))
# Out:
# For alpha 0.000001, the f1 score is 0.972786
# For alpha 0.000100, the f1 score is 0.973419
# For alpha 0.005000, the f1 score is 0.973596
# For alpha 0.007500, the f1 score is 0.973198
# For alpha 0.010000, the f1 score is 0.972861
# For alpha 0.030000, the f1 score is 0.972116
# For alpha 0.050000, the f1 score is 0.972101
# For alpha 0.100000, the f1 score is 0.971895
# For alpha 0.500000, the f1 score is 0.965600
# For alpha 1.000000, the f1 score is 0.954022

# %%
Mult = MultinomialNB(alpha=0.005)
Mult.fit(vectorizer.transform(train_data), train_labels) 
preds = Mult.predict(vectorizer.transform(test_data))

predictions = pd.DataFrame([test_data,test_labels,preds]).transpose()
#predictions

# %%
#predictions[predictions[1]<>predictions[2]]

# %%
#to_pred = new[pd.isnull(new["Cat2"])==True]
to_pred = new
print len(to_pred)
data_pred = to_pred["title"].as_matrix()
# Out:
# 100000

# %%
new_preds = Mult.predict(vectorizer.transform(data_pred))
new_predictions = pd.DataFrame([data_pred,new_preds]).transpose()
new_predictions
# Out:
#                                                        0                   1
# 0                           EU Passport 1:1 Good quality               Other
# 1                     The Walking Dead Seasons 1-4 (AVI)               Other
# 2                        Custom order for foryoumyfr13nd               Other
# 3                 250tabs x 250ug LSD ---FREE POSTAGE---        Psychadelics
# 4                           Breakthrough DMT sample 50mg        Psychadelics
# 5                                5 Gr of Speed Paste 72%          Stimulants
# 6                backroomcastingcouch.com Siterip (27GB)               Other
# 7                                   VIAGRA 10 PACKS OF 4  Sildenafil Citrate
# 8                    50x Green Herbal life 90-120MG MDMA             Ecstasy
# 9               Methenolone Enanthate - 10g - Primobolan     Steroids / PEDs
# 10                                          0.5g cocaine          Stimulants
# 11     14g - A$ 4000 Super Clean Sparkling Meth - Ora...          Stimulants
# 12     Pure Scopolamine - Devil's Breath - Burundanga...       Dissociatives
# 13     Darknet Tails Bootable USB 8GB (You create you...               Other
# 14                     100 g Malana Charas super natural            Cannabis
# 15                ***100 GRAM OF 72% PURE SPEED PASTE***          Stimulants
# 16            LADY ROSE SLIMS (10 packs x 20 cigarettes)               Other
# 17              1000x Gold Bar 200-220mg MDMA (new Wifi)             Ecstasy
# 18          Keyring Container For Example Pills & Powder               Other
# 19     ** US Pharmaceuticals Arimidex 1.5mg/ml 60ml *...               Other
# 20                    HIGH 80s COCAINE - UNCUT - 2 GRAMS          Stimulants
# 21                                200mg High Quality DMT        Psychadelics
# 22                           1gr Moroccan Nougat Hashish            Cannabis
# 23                                 10gr Pure Power Plant            Cannabis
# 24                               Deluxe Powder Mill 40mm               Other
# 25        250g Big Moonrock Methylone 99.9% Pure Crystal             Ecstasy
# 26                       100g Marlboro "Gold Stamp" Hash            Cannabis
# 27                   Symbiosis - 7g MDMA, UK First Class             Ecstasy
# 28               25D-NBOMe HCl (1000g) x200 blotter tabs        Psychadelics
# 29              Rolex - Submariner Yellow Gold [Replica]               Other
# ...                                                  ...                 ...
# 99970      ??? Girl Scout Cookies - 1 Ounce (28 Grams) |            Cannabis
# 99971                                           $100 USD           Relaxants
# 99972                      10 Regular Seeds (Random Mix)            Cannabis
# 99973  How to make 1000$ per week. Guide (contains 2 ...               Other
# 99974                   200gr.5-APB FREE SHIP WITH TRACK          Stimulants
# 99975  Mr Terrific's Terrific Golden Teacher Agar Cul...               Other
# 99976                5g of Speed --- Amphetamine sulfate          Stimulants
# 99977  HYDROCODONE (Watson) 10/325 mg :::60 Pills Pac...          Analgesics
# 99978             100 gr Uncut Pure Dutch HQ White MDMA.             Ecstasy
# 99979                         50g Gold Seal Afghani Hash            Cannabis
# 99980          500g Indian Ketamine shipped from Germany       Dissociatives
# 99981                             Potassium chlorate 1kg               Other
# 99982            100 grams pure lab grade 2C-B *LIMITED*        Psychadelics
# 99983  0.5g- A$ 230 Super Clean Sparkling Meth - Oran...          Stimulants
# 99984                    Cialis 40mg (Tadalafil) 100 Tab  Sildenafil Citrate
# 99985                  AHRAM ENERGY DRINK HOOKAH TOBACCO               Other
# 99986                     Testosterone propionate - 500g     Steroids / PEDs
# 99987                         500 ZOPICLONE 7.5 MG PILLS           Relaxants
# 99988  30mg Adderall XR (Manufactured by Shire) [Disc...          Stimulants
# 99989  5 x LSD blotter .....   250ug ...  ( medium st...        Psychadelics
# 99990                                         MXE - 100G       Dissociatives
# 99991  Brand Modalert (MODAFINIL) 30x200mg TOP qualit...          Stimulants
# 99992                    20gr.5-APB FREE SHIP WITH TRACK          Stimulants
# 99993               5 Dutch LSD Blotters - High Strength        Psychadelics
# 99994                   Masteron Propionate 100mg x 10ml     Steroids / PEDs
# 99995                     20G Afghan Heroin Brown Powder             Opioids
# 99996  Need BITCOINS? Trusted Round table vendor with...               Other
# 99997  100 x 183mg - Apple Macs 2014 -EXCTACY TABLETS...               Other
# 99998                                 custom - ilovevera               Other
# 99999  THC Suckers. Lemon Aide Flavor 100mg - 1x - FR...               Other
#
# [100000 rows x 2 columns]

# %%
#non_other = new_predictions[new_predictions[1]<>"Other"]
#non_other

# %%
new["Pred_Cat"] = new_predictions[1]

# %%
new[["title","Cat2","Pred_Cat"]].head(20)
# Out:
#                                                 title                Cat2  \
# 0                        EU Passport 1:1 Good quality                 NaN
# 1                  The Walking Dead Seasons 1-4 (AVI)                 NaN
# 2                     Custom order for foryoumyfr13nd               Other
# 3              250tabs x 250ug LSD ---FREE POSTAGE---        Psychadelics
# 4                        Breakthrough DMT sample 50mg        Psychadelics
# 5                             5 Gr of Speed Paste 72%          Stimulants
# 6             backroomcastingcouch.com Siterip (27GB)                 NaN
# 7                                VIAGRA 10 PACKS OF 4  Sildenafil Citrate
# 8                 50x Green Herbal life 90-120MG MDMA             Ecstasy
# 9            Methenolone Enanthate - 10g - Primobolan                 NaN
# 10                                       0.5g cocaine          Stimulants
# 11  14g - A$ 4000 Super Clean Sparkling Meth - Ora...                 NaN
# 12  Pure Scopolamine - Devil's Breath - Burundanga...       Dissociatives
# 13  Darknet Tails Bootable USB 8GB (You create you...                 NaN
# 14                  100 g Malana Charas super natural                 NaN
# 15             ***100 GRAM OF 72% PURE SPEED PASTE***          Stimulants
# 16         LADY ROSE SLIMS (10 packs x 20 cigarettes)                 NaN
# 17           1000x Gold Bar 200-220mg MDMA (new Wifi)             Ecstasy
# 18       Keyring Container For Example Pills & Powder                 NaN
# 19  ** US Pharmaceuticals Arimidex 1.5mg/ml 60ml *...                 NaN
#
#               Pred_Cat
# 0                Other
# 1                Other
# 2                Other
# 3         Psychadelics
# 4         Psychadelics
# 5           Stimulants
# 6                Other
# 7   Sildenafil Citrate
# 8              Ecstasy
# 9      Steroids / PEDs
# 10          Stimulants
# 11          Stimulants
# 12       Dissociatives
# 13               Other
# 14            Cannabis
# 15          Stimulants
# 16               Other
# 17             Ecstasy
# 18               Other
# 19               Other

# %%
#non_other.to_csv("non_other.csv",",",index=False)

# %%
#other = new_predictions[new_predictions[1]=="Other"]
#other
#other.to_csv("other.csv",",",index=False)

# %%
new2 = new[pd.isnull(new["SubCat2"])==False]
SubCat = ["MDMA", "Weed", "Cocaine", "LSD", "Benzos", "NBOMe", "Speed","Amphetamine",
              "Heroin","Xanax","2C","DMT","Methylone","Tramadol","Valium","Testosterone","Viagra"]
# new2 = new[new["Cat2"].isin(categories)]
len(new2)
# Out:
# 62601

# %%
new2["SubCat2"] = [x if x in SubCat else "Other" for x in new2["SubCat2"]]
#new2
# Out:
# C:\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data = new2["title"].as_matrix()
labels = new2["SubCat2"].as_matrix()

num_test = len(data)
test_data, test_labels = data[:num_test/4], labels[:num_test/4]
train_data, train_labels = data[num_test/4:], labels[num_test/4:]

print num_test
print len(test_data)
print len(train_data)
# Out:
# 62601
# 15650
# 46951

# %%
train_labels
# Out:
# array(['MDMA', 'Other', 'MDMA', ..., 'Heroin', 'Other', 'Other'], dtype=object)

# %%
#Initialize Count Vectorizer
vectorizer = TfidfVectorizer()
x=vectorizer.fit_transform(train_data)

for i in [0.000001,0.0001,0.005,0.0075,0.01,0.03,0.05,0.1,0.5,1]:
    Mult = MultinomialNB(alpha=i)
    Mult.fit(vectorizer.transform(train_data), train_labels) 
    preds = Mult.predict(vectorizer.transform(test_data))
    
    print "For alpha %f, the f1 score is %f" %(i, metrics.f1_score(test_labels,preds,average="weighted"))
# Out:
# For alpha 0.000001, the f1 score is 0.970976
# For alpha 0.000100, the f1 score is 0.970670
# For alpha 0.005000, the f1 score is 0.969886
# For alpha 0.007500, the f1 score is 0.969887
# For alpha 0.010000, the f1 score is 0.969764
# For alpha 0.030000, the f1 score is 0.968452
# For alpha 0.050000, the f1 score is 0.969215
# For alpha 0.100000, the f1 score is 0.968318
# For alpha 0.500000, the f1 score is 0.948577
# For alpha 1.000000, the f1 score is 0.922688

# %%
Mult = MultinomialNB(alpha=0.000001)
Mult.fit(vectorizer.transform(train_data), train_labels) 
preds = Mult.predict(vectorizer.transform(test_data))

predictions = pd.DataFrame([test_data,test_labels,preds]).transpose()
#predictions

# %%
predictions[predictions[1]<>predictions[2]]
# Out:
#                                                        0             1  \
# 123    14g - A$ 4000 Super Clean Sparkling Meth - Ora...   Amphetamine
# 177                                      3.5g meth (ice)         Other
# 196                                  10g Swazi Gold Kief         Other
# 208    INTRO OFFER SAMPLE MY MDMA 3.5g - THIS IS THE ...          MDMA
# 265                                        5F-PB-22 - 5g         Other
# 268    HALF PRICE FOR REGULARS !!!!  100 X 2mg Rivotr...        Benzos
# 309                                  VALIUM 10mg generic        Valium
# 331    28g - A$ 7500 Super Clean Sparkling Meth - Ora...         Other
# 334                               7g HQ Liberty Haze A |          Weed
# 395    30x "CIALIS" 20mg tadalafil tablets, brand nam...         Other
# 446                                  5F-AB-PINACA - 100g         Other
# 473                              2x Vanilla Fudge pieces         Other
# 548                                    METH GREAT ICE !!         Other
# 559    Ajanta Kamagra Tablets to water 100mg/tab [7 t...         Other
# 584                          112g - QP - SHAKE/TRIMMINGS         Other
# 623                    1 GRAM TOP SHELF RICK SIMPSON OIL         Other
# 629    Co2 - THC Cartridge and Vape Pen combo Qty 25 ...         Other
# 710              Ethylone (BK-MDEA) Big Crystals - 1000g         Other
# 717           1 LB (453g) Mr. Nice Guy MNG Greenhouse GH          Weed
# 722         Special! 4 Grams WHITE FIRE OG Honeycomb Wax         Other
# 764                 4 x 20mg Tadacip 20 (Cialis) tablets         Speed
# 774                    1 gram HQ Meth ICE Crystal Shards         Other
# 796       1 oz Malana Charas Cream! Imported from India!         Other
# 802                                0,5 Gram Crystal Meth         Other
# 927                               Custom for Largestacks          Weed
# 974                     One Full gram #4 Pakistan Heroin        Heroin
# 976            1x 500x Blotter Art Sheet  UK - Worldwide           LSD
# 994    150mg Vyvanse Lisdexamfetamine dimesylate (5x ...   Amphetamine
# 1028                            custom Irba   Ya Ba x 40         Speed
# 1040   Custom - 500 gr. ~ 72% Pure Speed Paste  20 gr...          MDMA
# ...                                                  ...           ...
# 14770                   UGLoz Sustanon 250mg/ml 5 X 10ml         Other
# 14857                                 10x Domino 220MG |         Other
# 14896  Deep Dish Monopoly (28g) AoD's Crystal Methamp...   Amphetamine
# 14993                                Granulated Sex Salt         Other
# 15011                       Grundlesnake private listing        Heroin
# 15035  30x "CIALIS" 20mg tadalafil tablets, brand nam...         Other
# 15047                  A1 PURE COCAINE 0.2G SAMPLE 22.00       Cocaine
# 15051  SPECIAL START OFFER!  -*18g *-100  -~Special H...          Weed
# 15064                            Ativan 2 MG (500 Pills)         Other
# 15079             1 x UGL Oz Sustanon 250  250mg/ml 10ml         Other
# 15083                  Rip 300 10ml multi injection vial         Other
# 15133  Xanax 1mg by Pfizer 14 strips / 140 tabs in Bl...         Xanax
# 15148   Shatter Concentrate 1/4 ounce 7 Grams Death Star         Other
# 15174                                          8x valium        Valium
# 15192                                   10x Domino 200mg         Other
# 15199  500x  2C-B  Blue Hearts (16mg)  only available...            2C
# 15224                         PURE XANAX POWDER 10 GRAMS         Xanax
# 15234          UGL OZ Masteron Enanthate 200mg/mL (10mL)         Other
# 15296                         Flurazepam 30mg - 10 pills        Benzos
# 15365  -*Special Herbal Smoke Blend*-  -  50g -   -AM...          Weed
# 15399                        Dutch Bugatti Pills 200mg |         Other
# 15455                  20 gr. 2 C-P FREE SHIP WITH TRACK            2C
# 15468                        1kg Ethylone / E1 / BK-MDEA         Other
# 15475                            Actavis 5mg valium x 28        Valium
# 15496                *** 1000GR 72% PURE SPEED PASTA ***         Speed
# 15544  4X Generic Cialis 20mg ( Tadalafil Tablets ) B...         Other
# 15587                  250Gr. Ketamine 84% Pureness Bulk         Other
# 15611  TESTOSTERONE ENANTHATE (bayer pharmacueticals)...  Testosterone
# 15632                                   AB-PINACA - 500g         Other
# 15648   Hinga custom lisiting ***charlie sheen 5grams***         Other
#
#                   2
# 123           Other
# 177     Amphetamine
# 196            Weed
# 208           Other
# 265            Weed
# 268           Other
# 309          Benzos
# 331     Amphetamine
# 334           Other
# 395          Viagra
# 446            Weed
# 473            Weed
# 548     Amphetamine
# 559          Viagra
# 584            Weed
# 623            Weed
# 629            Weed
# 710       Methylone
# 717           Other
# 722            Weed
# 764           Other
# 774     Amphetamine
# 796            Weed
# 802     Amphetamine
# 927           Other
# 974           Other
# 976           Other
# 994           Other
# 1028          Other
# 1040          Speed
# ...             ...
# 14770  Testosterone
# 14857          MDMA
# 14896         Other
# 14993           DMT
# 15011         Other
# 15035        Viagra
# 15047         Other
# 15051         Other
# 15064        Benzos
# 15079  Testosterone
# 15083  Testosterone
# 15133        Benzos
# 15148          Weed
# 15174         Other
# 15192          MDMA
# 15199         Other
# 15224        Benzos
# 15234  Testosterone
# 15296         Other
# 15365         Other
# 15399          MDMA
# 15455         Other
# 15468     Methylone
# 15475        Benzos
# 15496         Other
# 15544        Viagra
# 15587          MDMA
# 15611         Other
# 15632          Weed
# 15648       Cocaine
#
# [455 rows x 3 columns]

# %%
#to_pred = new[pd.isnull(new["Cat2"])==True]
to_pred = new
print len(to_pred)
data_pred = to_pred["title"].as_matrix()
# Out:
# 100000

# %%
new_preds = Mult.predict(vectorizer.transform(data_pred))
new_predictions = pd.DataFrame([data_pred,new_preds]).transpose()
new_predictions
# Out:
#                                                        0             1
# 0                           EU Passport 1:1 Good quality         Other
# 1                     The Walking Dead Seasons 1-4 (AVI)         Other
# 2                        Custom order for foryoumyfr13nd         Other
# 3                 250tabs x 250ug LSD ---FREE POSTAGE---           LSD
# 4                           Breakthrough DMT sample 50mg           DMT
# 5                                5 Gr of Speed Paste 72%         Speed
# 6                backroomcastingcouch.com Siterip (27GB)         Other
# 7                                   VIAGRA 10 PACKS OF 4        Viagra
# 8                    50x Green Herbal life 90-120MG MDMA          MDMA
# 9               Methenolone Enanthate - 10g - Primobolan         Other
# 10                                          0.5g cocaine       Cocaine
# 11     14g - A$ 4000 Super Clean Sparkling Meth - Ora...         Other
# 12     Pure Scopolamine - Devil's Breath - Burundanga...         Other
# 13     Darknet Tails Bootable USB 8GB (You create you...         Other
# 14                     100 g Malana Charas super natural          Weed
# 15                ***100 GRAM OF 72% PURE SPEED PASTE***         Speed
# 16            LADY ROSE SLIMS (10 packs x 20 cigarettes)         Other
# 17              1000x Gold Bar 200-220mg MDMA (new Wifi)          MDMA
# 18          Keyring Container For Example Pills & Powder         Other
# 19     ** US Pharmaceuticals Arimidex 1.5mg/ml 60ml *...         Other
# 20                    HIGH 80s COCAINE - UNCUT - 2 GRAMS       Cocaine
# 21                                200mg High Quality DMT           DMT
# 22                           1gr Moroccan Nougat Hashish          Weed
# 23                                 10gr Pure Power Plant          Weed
# 24                               Deluxe Powder Mill 40mm         Other
# 25        250g Big Moonrock Methylone 99.9% Pure Crystal     Methylone
# 26                       100g Marlboro "Gold Stamp" Hash          Weed
# 27                   Symbiosis - 7g MDMA, UK First Class          MDMA
# 28               25D-NBOMe HCl (1000g) x200 blotter tabs         NBOMe
# 29              Rolex - Submariner Yellow Gold [Replica]         Other
# ...                                                  ...           ...
# 99970      ??? Girl Scout Cookies - 1 Ounce (28 Grams) |          Weed
# 99971                                           $100 USD         Other
# 99972                      10 Regular Seeds (Random Mix)          Weed
# 99973  How to make 1000$ per week. Guide (contains 2 ...         Other
# 99974                   200gr.5-APB FREE SHIP WITH TRACK         Other
# 99975  Mr Terrific's Terrific Golden Teacher Agar Cul...         Other
# 99976                5g of Speed --- Amphetamine sulfate   Amphetamine
# 99977  HYDROCODONE (Watson) 10/325 mg :::60 Pills Pac...         Other
# 99978             100 gr Uncut Pure Dutch HQ White MDMA.          MDMA
# 99979                         50g Gold Seal Afghani Hash          Weed
# 99980          500g Indian Ketamine shipped from Germany         Other
# 99981                             Potassium chlorate 1kg         Other
# 99982            100 grams pure lab grade 2C-B *LIMITED*            2C
# 99983  0.5g- A$ 230 Super Clean Sparkling Meth - Oran...         Other
# 99984                    Cialis 40mg (Tadalafil) 100 Tab         Other
# 99985                  AHRAM ENERGY DRINK HOOKAH TOBACCO         Other
# 99986                     Testosterone propionate - 500g  Testosterone
# 99987                         500 ZOPICLONE 7.5 MG PILLS         Other
# 99988  30mg Adderall XR (Manufactured by Shire) [Disc...         Other
# 99989  5 x LSD blotter .....   250ug ...  ( medium st...           LSD
# 99990                                         MXE - 100G         Other
# 99991  Brand Modalert (MODAFINIL) 30x200mg TOP qualit...         Other
# 99992                    20gr.5-APB FREE SHIP WITH TRACK         Other
# 99993               5 Dutch LSD Blotters - High Strength           LSD
# 99994                   Masteron Propionate 100mg x 10ml  Testosterone
# 99995                     20G Afghan Heroin Brown Powder        Heroin
# 99996  Need BITCOINS? Trusted Round table vendor with...         Other
# 99997  100 x 183mg - Apple Macs 2014 -EXCTACY TABLETS...         Other
# 99998                                 custom - ilovevera         Other
# 99999  THC Suckers. Lemon Aide Flavor 100mg - 1x - FR...         Other
#
# [100000 rows x 2 columns]

# %%
new["Pred_Sub_Cat"] = new_predictions[1]

# %%
new[["title","Cat2","Pred_Cat","SubCat2","Pred_Sub_Cat"]].head(20)
# Out:
#                                                 title                Cat2  \
# 0                        EU Passport 1:1 Good quality                 NaN
# 1                  The Walking Dead Seasons 1-4 (AVI)                 NaN
# 2                     Custom order for foryoumyfr13nd               Other
# 3              250tabs x 250ug LSD ---FREE POSTAGE---        Psychadelics
# 4                        Breakthrough DMT sample 50mg        Psychadelics
# 5                             5 Gr of Speed Paste 72%          Stimulants
# 6             backroomcastingcouch.com Siterip (27GB)                 NaN
# 7                                VIAGRA 10 PACKS OF 4  Sildenafil Citrate
# 8                 50x Green Herbal life 90-120MG MDMA             Ecstasy
# 9            Methenolone Enanthate - 10g - Primobolan                 NaN
# 10                                       0.5g cocaine          Stimulants
# 11  14g - A$ 4000 Super Clean Sparkling Meth - Ora...                 NaN
# 12  Pure Scopolamine - Devil's Breath - Burundanga...       Dissociatives
# 13  Darknet Tails Bootable USB 8GB (You create you...                 NaN
# 14                  100 g Malana Charas super natural                 NaN
# 15             ***100 GRAM OF 72% PURE SPEED PASTE***          Stimulants
# 16         LADY ROSE SLIMS (10 packs x 20 cigarettes)                 NaN
# 17           1000x Gold Bar 200-220mg MDMA (new Wifi)             Ecstasy
# 18       Keyring Container For Example Pills & Powder                 NaN
# 19  ** US Pharmaceuticals Arimidex 1.5mg/ml 60ml *...                 NaN
#
#               Pred_Cat      SubCat2 Pred_Sub_Cat
# 0                Other          NaN        Other
# 1                Other          NaN        Other
# 2                Other      Alcohol        Other
# 3         Psychadelics          LSD          LSD
# 4         Psychadelics          DMT          DMT
# 5           Stimulants        Speed        Speed
# 6                Other          NaN        Other
# 7   Sildenafil Citrate       Viagra       Viagra
# 8              Ecstasy         MDMA         MDMA
# 9      Steroids / PEDs          NaN        Other
# 10          Stimulants      Cocaine      Cocaine
# 11          Stimulants          NaN        Other
# 12       Dissociatives  Scopolamine        Other
# 13               Other          NaN        Other
# 14            Cannabis          NaN         Weed
# 15          Stimulants        Speed        Speed
# 16               Other          NaN        Other
# 17             Ecstasy         MDMA         MDMA
# 18               Other          NaN        Other
# 19               Other          NaN        Other

# %%
#Export new data to csv file
new.to_csv("categorized_output.csv",",",index=False)
